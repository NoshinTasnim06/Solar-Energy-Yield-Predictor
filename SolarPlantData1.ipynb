# %%
import pandas as pd

# %%
spd1 = pd.read_csv('/Users/noshintasnim/Downloads/Solar Power Generation Project/Raw Data/solar_plant_generation_dataset.csv')

# %%
spd1.head(10)
# Out:
#              timestamp  solar_irradiance_wm2  ambient_temperature_c  \
# 0  2025-01-01 00:00:00                  0.00                  23.06
# 1  2025-01-01 01:00:00                  0.00                  28.04
# 2  2025-01-01 02:00:00                  0.00                  24.97
# 3  2025-01-01 03:00:00                  0.00                  17.90
# 4  2025-01-01 04:00:00                  0.00                  24.27
# 5  2025-01-01 05:00:00                  0.00                  21.94
# 6  2025-01-01 06:00:00                  0.00                  29.03
# 7  2025-01-01 07:00:00                162.82                  34.43
# 8  2025-01-01 08:00:00                356.83                  26.77
# 9  2025-01-01 09:00:00                415.52                  25.94
#
#    panel_temperature_c  cloud_cover_percent  power_generation_kw
# 0                23.06                35.37                 0.00
# 1                28.04                20.70                 0.00
# ...

# %%
spd1.columns
# Out:
# Index(['timestamp', 'solar_irradiance_wm2', 'ambient_temperature_c',
#        'panel_temperature_c', 'cloud_cover_percent', 'power_generation_kw'],
#       dtype='object')

# %%
spd1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   timestamp              5000 non-null   object
#  1   solar_irradiance_wm2   5000 non-null   float64
#  2   ambient_temperature_c  5000 non-null   float64
#  3   panel_temperature_c    5000 non-null   float64
#  4   cloud_cover_percent    5000 non-null   float64
#  5   power_generation_kw    5000 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 234.5+ KB

# %%
spd1 =spd1.rename(columns={'timestamp': 'Timestamp', 'solar_irradiance_wm2': 'Irradiance', 'ambient_temperature_c': 'Ambient_Temperature',
                    'panel_temperature_c': 'Module_Temperature','cloud_cover_percent': 'Cloud_Cover',
                    'power_generation_kw': 'Power_Generation'})

spd1.insert(1, 'Plant_ID', 4137001)

# %%
spd1.head(24)
# Out:
#               Timestamp  Plant_ID  Irradiance  Ambient_Temperature  \
# 0   2025-01-01 00:00:00   4137001        0.00                23.06
# 1   2025-01-01 01:00:00   4137001        0.00                28.04
# 2   2025-01-01 02:00:00   4137001        0.00                24.97
# 3   2025-01-01 03:00:00   4137001        0.00                17.90
# 4   2025-01-01 04:00:00   4137001        0.00                24.27
# 5   2025-01-01 05:00:00   4137001        0.00                21.94
# 6   2025-01-01 06:00:00   4137001        0.00                29.03
# 7   2025-01-01 07:00:00   4137001      162.82                34.43
# 8   2025-01-01 08:00:00   4137001      356.83                26.77
# 9   2025-01-01 09:00:00   4137001      415.52                25.94
# 10  2025-01-01 10:00:00   4137001      694.01                26.26
# 11  2025-01-01 11:00:00   4137001      769.97                34.88
# 12  2025-01-01 12:00:00   4137001      716.99                34.77
# ...

# %%
spd1.isna().any()
# Out:
# Timestamp              False
# Plant_ID               False
# Irradiance             False
# Ambient_Temperature    False
# Module_Temperature     False
# Cloud_Cover            False
# Power_Generation       False
# dtype: bool
